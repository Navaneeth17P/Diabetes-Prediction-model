# %%
# %matplotlib inline
### import libraries
import numpy as np
import pandas as pd


import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns

# %%
df = pd.read_csv('health care diabetes.csv')
df.head(5)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.shape
# Out:
# (768, 9)

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
Col=df.iloc[:,0:8].columns
plt.figure(figsize=(15,15))
for i,j in enumerate(Col):
    plt.subplot(4,2,i+1)
    sns.set_style('whitegrid')
    sns.histplot(df[j], color='red')
    plt.xlabel('')
    plt.title('{}'.format(j), size=13)
plt.show()

# %%
#Checking for zero values in the 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI' columns.
df.columns
Columns=['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']
for i in Columns:
     if ((df[i]==0).sum()) >= 0:
            print('Column', i ,'has entires as zero')
            print('Number of zero entries is:', (df[i]==0).sum())
            print('------------------------------------------------')
# Out:
# Column Glucose has entires as zero
# Number of zero entries is: 5
# ------------------------------------------------
# Column BloodPressure has entires as zero
# Number of zero entries is: 35
# ------------------------------------------------
# Column SkinThickness has entires as zero
# Number of zero entries is: 227
# ------------------------------------------------
# Column Insulin has entires as zero
# Number of zero entries is: 374
# ------------------------------------------------
# Column BMI has entires as zero
# Number of zero entries is: 11
# ------------------------------------------------

# %%
Columns=['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']
for i in Columns:
    print(df[i].describe())
    print('------------------------------------------------')
# Out:
# count    768.000000
# mean     120.894531
# std       31.972618
# min        0.000000
# 25%       99.000000
# 50%      117.000000
# 75%      140.250000
# max      199.000000
# Name: Glucose, dtype: float64
# ------------------------------------------------
# count    768.000000
# mean      69.105469
# std       19.355807
# min        0.000000
# 25%       62.000000
# 50%       72.000000
# 75%       80.000000
# max      122.000000
# Name: BloodPressure, dtype: float64
# ------------------------------------------------
# count    768.000000
# mean      20.536458
# std       15.952218
# min        0.000000
# 25%        0.000000
# 50%       23.000000
# 75%       32.000000
# max       99.000000
# Name: SkinThickness, dtype: float64
# ------------------------------------------------
# count    768.000000
# mean      79.799479
# std      115.244002
# min        0.000000
# 25%        0.000000
# 50%       30.500000
# 75%      127.250000
# max      846.000000
# Name: Insulin, dtype: float64
# ------------------------------------------------
# count    768.000000
# mean      31.992578
# std        7.884160
# min        0.000000
# 25%       27.300000
# 50%       32.000000
# 75%       36.600000
# max       67.100000
# Name: BMI, dtype: float64
# ------------------------------------------------

# %%
Columns=['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']
for i in Columns:
    print('The median value of', i ,'is',df[i].median())
    print('------------------------------------------------')
# Out:
# The median value of Glucose is 117.0
# ------------------------------------------------
# The median value of BloodPressure is 72.0
# ------------------------------------------------
# The median value of SkinThickness is 23.0
# ------------------------------------------------
# The median value of Insulin is 30.5
# ------------------------------------------------
# The median value of BMI is 32.0
# ------------------------------------------------

# %%
#Checking the distribution of column
Columns=['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']
plt.figure(figsize=(15,15))
for i,j in enumerate(Columns):
    plt.subplot(3,2,i+1)
    sns.set_style('whitegrid')
    sns.histplot(df[j], color='red')
    plt.xlabel('')
    plt.title('{}'.format(j), size=13)
plt.show()

# %%
#Replacing the zero values with median value of respective column
Columns=['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']
for i in Columns:
    df[i] = df[i].replace(0,df[i].median())
    
Columns=['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']
for i in Columns:
     if ((df[i]==0).sum()) == 0:
            print('Column', i ,'has No entires as zero')
# Out:
# Column Glucose has No entires as zero
# Column BloodPressure has No entires as zero
# Column SkinThickness has No entires as zero
# Column Insulin has No entires as zero
# Column BMI has No entires as zero

# %%
Columns=['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']
plt.figure(figsize=(15,15))
for i,j in enumerate(Columns):
    plt.subplot(3,2,i+1)
    sns.set_style('whitegrid')
    sns.histplot(df[j], color='red')
    plt.xlabel('')
    plt.title('{}'.format(j), size=13)
plt.show()

# %%
plt.subplots(figsize=(8,8))
sns.heatmap(df.corr(),annot=True,cmap='viridis')  ### gives correlation value
# Out:
# <AxesSubplot:>

# %%
col=df.columns
sns.pairplot(df[col])

# %%
#Checking for balance of the dataset
df['Outcome'].value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state = 2)
df_Balanched= sm.fit_sample(df.ravel())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [23], in <cell line: 1>()
# ----> 1 from imblearn.over_sampling import SMOTE
#       2 sm = SMOTE(random_state = 2)
#       3 df_Balanched= sm.fit_sample(df.ravel())
#
# ModuleNotFoundError: No module named 'imblearn'

# %%
df.skew()
# Out:
# Pregnancies                 0.901674
# Glucose                     0.535587
# BloodPressure               0.141885
# SkinThickness               1.223057
# Insulin                     2.693181
# BMI                         0.601059
# DiabetesPedigreeFunction    1.919911
# Age                         1.129597
# Outcome                     0.635017
# dtype: float64

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df_ND= df[['Glucose', 'SkinThickness', 'Insulin','BMI', 'DiabetesPedigreeFunction', 'Age']].apply(np.log, axis = 1).round(3)
df_ND.skew()
# Out:
# Glucose                    -0.064510
# SkinThickness              -0.289245
# Insulin                     0.751311
# BMI                        -0.054444
# DiabetesPedigreeFunction    0.114109
# Age                         0.601621
# dtype: float64

# %%
df_ND['Pregnancies']=df['Pregnancies']
df_ND['BloodPressure']=df['BloodPressure']
df_ND['Outcome']=df['Outcome']
df_ND
# Out:
#      Glucose  SkinThickness  Insulin    BMI  DiabetesPedigreeFunction    Age  \
# 0      4.997          3.555    3.418  3.515                    -0.467  3.912
# 1      4.443          3.367    3.418  3.281                    -1.047  3.434
# 2      5.209          3.135    3.418  3.148                    -0.397  3.466
# 3      4.489          3.135    4.543  3.336                    -1.790  3.045
# 4      4.920          3.555    5.124  3.764                     0.828  3.497
# ..       ...            ...      ...    ...                       ...    ...
# 763    4.615          3.871    5.193  3.493                    -1.766  4.143
# 764    4.804          3.296    3.418  3.605                    -1.079  3.296
# 765    4.796          3.135    4.718  3.266                    -1.406  3.401
# 766    4.836          3.135    3.418  3.405                    -1.053  3.850
# 767    4.533          3.434    3.418  3.414                    -1.155  3.135
#
#      Pregnancies  BloodPressure  Outcome
# 0              6             72        1
# 1              1             66        0
# 2              8             64        1
# 3              1             66        0
# 4              0             40        1
# ..           ...            ...      ...
# 763           10             76        0
# 764            2             70        0
# 765            5             72        0
# 766            1             60        1
# 767            1             70        0
#
# [768 rows x 9 columns]

# %%
# Selecting columns for preprocessing
df_ND_PP=df.iloc[:,0:8]
df_ND_PP
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35     30.5  33.6
# 1              1       85             66             29     30.5  26.6
# 2              8      183             64             23     30.5  23.3
# 3              1       89             66             23     94.0  28.1
# 4              0      137             40             35    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48    180.0  32.9
# 764            2      122             70             27     30.5  36.8
# 765            5      121             72             23    112.0  26.2
# 766            1      126             60             23     30.5  30.1
# 767            1       93             70             31     30.5  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# 2                       0.672   32
# 3                       0.167   21
# 4                       2.288   33
# ..                        ...  ...
# 763                     0.171   63
# 764                     0.340   27
# 765                     0.245   30
# 766                     0.349   47
# 767                     0.315   23
#
# [768 rows x 8 columns]

# %%
from sklearn.preprocessing import RobustScaler
from sklearn import preprocessing
scaler = RobustScaler()

scaler = preprocessing.RobustScaler()
df_scaled = scaler.fit_transform(df_ND_PP)
df_scaled = pd.DataFrame(df_ND_PP)
df_scaled.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  121.656250      72.386719      27.334635   94.652344
# std       3.369578   30.438286      12.096642       9.229014  105.547598
# min       0.000000   44.000000      24.000000       7.000000   14.000000
# 25%       1.000000   99.750000      64.000000      23.000000   30.500000
# 50%       3.000000  117.000000      72.000000      23.000000   31.250000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age
# count  768.000000                768.000000  768.000000
# mean    32.450911                  0.471876   33.240885
# std      6.875366                  0.331329   11.760232
# min     18.200000                  0.078000   21.000000
# 25%     27.500000                  0.243750   24.000000
# 50%     32.000000                  0.372500   29.000000
# 75%     36.600000                  0.626250   41.000000
# max     67.100000                  2.420000   81.000000

# %% [markdown]
# # Week 2

# %%
# Logistic Regreation and model building

# %%
data.head(5)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
features = data.iloc[:,[0,1,2,3,4,5,6,7]].values
label = data.iloc[:,8].values

# %%
#Train test split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(features,label,test_size=0.2,random_state =10)

# %%
#Create model
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train,y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
print(model.score(X_train,y_train))
print(model.score(X_test,y_test))
# Out:
# 0.7833876221498371
# 0.7337662337662337

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(label,model.predict(features))
cm
# Out:
# array([[452,  48],
#        [126, 142]], dtype=int64)

# %%
from sklearn.metrics import classification_report
print(classification_report(label,model.predict(features)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.90      0.84       500
#            1       0.75      0.53      0.62       268
#
#    micro avg       0.77      0.77      0.77       768
#    macro avg       0.76      0.72      0.73       768
# weighted avg       0.77      0.77      0.76       768

# %%
#Preparing ROC Curve (Receiver Operating Characteristics Curve)
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score

# predict probabilities
probs = model.predict_proba(features)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
auc = roc_auc_score(label, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
fpr, tpr, thresholds = roc_curve(label, probs)
# plot no skill
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr, tpr, marker='.')
# Out:
# AUC: 0.834

# %%
#Applying Decission Tree Classifier
from sklearn.tree import DecisionTreeClassifier
model3 = DecisionTreeClassifier(max_depth=5)
model3.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=5,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
model3.score(X_train,y_train)
# Out:
# 0.990228013029316

# %%
model3.score(X_test,y_test)
# Out:
# 0.7532467532467533

# %%
#Applying Random Forest
from sklearn.ensemble import RandomForestClassifier
model4 = RandomForestClassifier(n_estimators=11)
model4.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=11, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
model4.score(X_train,y_train)
# Out:
# 0.990228013029316

# %%
model4.score(X_test,y_test)
# Out:
# 0.7532467532467533

# %%
#Support Vector Classifier

from sklearn.svm import SVC 
model5 = SVC(kernel='rbf',
           gamma='auto')
model5.fit(X_train,y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
model5model.score(X_test,y_test).score(X_train,y_train)
# Out:
# 1.0

# %%
model5.score(X_test,y_test)
# Out:
# 0.6168831168831169

# %%
#Applying K-NN
from sklearn.neighbors import KNeighborsClassifier
model2 = KNeighborsClassifier(n_neighbors=7,
                             metric='minkowski',
                             p = 2)
model2.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=7, p=2,
#            weights='uniform')

# %%
#Preparing ROC Curve (Receiver Operating Characteristics Curve)
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score

# predict probabilities
probs = model2.predict_proba(features)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
auc = roc_auc_score(label, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
fpr, tpr, thresholds = roc_curve(label, probs)
print("True Positive Rate - {}, False Positive Rate - {} Thresholds - {}".format(tpr,fpr,thresholds))
# plot no skill
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr, tpr, marker='.')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
# Out:
# AUC: 0.836
# True Positive Rate - [0.         0.06716418 0.23880597 0.44776119 0.60074627 0.75373134
#  0.88059701 0.98507463 1.        ], False Positive Rate - [0.    0.    0.02  0.056 0.12  0.248 0.428 0.668 1.   ] Thresholds - [2.         1.         0.85714286 0.71428571 0.57142857 0.42857143
#  0.28571429 0.14285714 0.        ]
# Text(0, 0.5, 'True Positive Rate')

# %%
#Precision Recall Curve for Logistic Regression

from sklearn.metrics import precision_recall_curve
from sklearn.metrics import f1_score
from sklearn.metrics import auc
from sklearn.metrics import average_precision_score
# predict probabilities
probs = model.predict_proba(features)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# predict class values
yhat = model.predict(features)
# calculate precision-recall curve
precision, recall, thresholds = precision_recall_curve(label, probs)
# calculate F1 score
f1 = f1_score(label, yhat)
# calculate precision-recall AUC
auc = auc(recall, precision)
# calculate average precision score
ap = average_precision_score(label, probs)
print('f1=%.3f auc=%.3f ap=%.3f' % (f1, auc, ap))
# plot no skill
plt.plot([0, 1], [0.5, 0.5], linestyle='--')
# plot the precision-recall curve for the model
plt.plot(recall, precision, marker='.')
# Out:
# f1=0.620 auc=0.728 ap=0.728

# %%
#Precision Recall Curve for KNN

from sklearn.metrics import precision_recall_curve
from sklearn.metrics import f1_score
from sklearn.metrics import auc
from sklearn.metrics import average_precision_score
# predict probabilities
probs = model2.predict_proba(features)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# predict class values
yhat = model2.predict(features)
# calculate precision-recall curve
precision, recall, thresholds = precision_recall_curve(label, probs)
# calculate F1 score
f1 = f1_score(label, yhat)
# calculate precision-recall AUC
auc = auc(recall, precision)
# calculate average precision score
ap = average_precision_score(label, probs)
print('f1=%.3f auc=%.3f ap=%.3f' % (f1, auc, ap))
# plot no skill
plt.plot([0, 1], [0.5, 0.5], linestyle='--')
# plot the precision-recall curve for the model
plt.plot(recall, precision, marker='.')
# Out:
# f1=0.658 auc=0.752 ap=0.709

# %%
#Precision Recall Curve for Decission Tree Classifier

from sklearn.metrics import precision_recall_curve
from sklearn.metrics import f1_score
from sklearn.metrics import auc
from sklearn.metrics import average_precision_score
# predict probabilities
probs = model3.predict_proba(features)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# predict class values
yhat = model3.predict(features)
# calculate precision-recall curve
precision, recall, thresholds = precision_recall_curve(label, probs)
# calculate F1 score
f1 = f1_score(label, yhat)
# calculate precision-recall AUC
auc = auc(recall, precision)
# calculate average precision score
ap = average_precision_score(label, probs)
print('f1=%.3f auc=%.3f ap=%.3f' % (f1, auc, ap))
# plot no skill
plt.plot([0, 1], [0.5, 0.5], linestyle='--')
# plot the precision-recall curve for the model
plt.plot(recall, precision, marker='.')
# Out:
# f1=0.916 auc=0.966 ap=0.958

# %%
#Precision Recall Curve for Random Forest

from sklearn.metrics import precision_recall_curve
from sklearn.metrics import f1_score
from sklearn.metrics import auc
from sklearn.metrics import average_precision_score
# predict probabilities
probs = model4.predict_proba(features)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# predict class values
yhat = model4.predict(features)
# calculate precision-recall curve
precision, recall, thresholds = precision_recall_curve(label, probs)
# calculate F1 score
f1 = f1_score(label, yhat)
# calculate precision-recall AUC
auc = auc(recall, precision)
# calculate average precision score
ap = average_precision_score(label, probs)
print('f1=%.3f auc=%.3f ap=%.3f' % (f1, auc, ap))
# plot no skill
plt.plot([0, 1], [0.5, 0.5], linestyle='--')
# plot the precision-recall curve for the model
plt.plot(recall, precision, marker='.')
# Out:
# f1=0.914 auc=0.968 ap=0.960
